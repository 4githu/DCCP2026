# %%
text = "Hello, World!

print(text.strip()) # 양쪽 공백 제거
print(text.strip().lower()) # 소문자로
print(text.strip().upper()) # 대문자로
print(text.strip().replace("World", "Python")) # 문자열 대체
print ("Hello".startswith("He")) # 접두사 확인
print("Hello World".split()) # 문자열 분리
print("-".join(["a", "b", "c"])) # 문자열 결합

#문자열은 불변이다
text[0] = "h" # 오류 발생
text = "h" + text[1:] # 새로운 문자열 생성

# /의 결과는 항상 float
# 파이썬의 비교 연산자 : 수학처럼 1 < x < 10 같은게 가능
# is와 = 과 in의 차이 : is는 객체의 동일성, =는 변수에 값 할당, in은 멤버십 테스트
# 삼항 연산자 : a if condition else b

# 함수에서..
# 기본값 있는 변수가 기본값 없는 변수보다 뒤에 와야 한다.
# 매개변수 이름 명시시 순서 바꿔도 ㄱㅊ
# 타입 힌트 : 안 지켜도 오류 x ex. def greet(name: str) -> str:

#f-strings : f"Hello, {name}!" # 중괄호 안에 표현식 가능
# 소수점 자릿수 : {x.nf} ~> 응용 : .1%
# 정렬과 채우기 : {x:10} # 오른쪽 정렬, {x:<10} # 왼쪽 정렬, {x:^10} # 가운데 정렬
    # x:y^n : x 가운데 정렬하고 남는 문자 y로 채우기
    # 0nd : 최소 n자리, 빈칸은 0으로 채우기
    # , : 천 단위 구분자
# 진법 변환
# 2진수 : {x:b}, 8진수 : {x:o}, 16진수 : {x:x} (소문자), {x:X} (대문자), {x:#x} (0x 접두사 포함) {x:d} (10진수)
# 디버깅용 : {x=} : x = 값 출력




# 요소 추가 : append() / insert( , ) 특정위치 삽입 / extend(리스트) 여러 요소 추가
# 요소 제거 : remove(값) / pop() 마지막 요소 제거 후 반환 / pop(인덱스) 특정 위치 요소 제거 후 반환 / del : 특정 인덱스 요소 제거 / clear() 모든 요소 제거

# 어떤 함수와 ed 붙은 함수 차이 : ed 붙으면 새 리스트, 아니면 원본 변경
    # ex. sort / sorted , reverse / reversed (순서 뒤집기), copy / copied (얕은 복사) , append / appended (요소 추가) , remove / removed (요소 제거), count / counted (요소 개수 세기), index / indexed (요소 위치 찾기), len / length (리스트 길이), sum / summed (리스트 요소 합계), min / minimum (최소값), max / maximum (최대값)
# 리스트 컴프리헨션에서 if만 넣으면 조건 맞는것만 들어옴

# 언패킹
# a, b = [1, 2] # 리스트 언패킹 () 면 튜플
# a, b, *rest = [1, 2, 3, 4] # 나머지 요소는 rest에 리스트로 저장
# _는 무시할 때 사용
# tip! a, b = b, a 하면 빠른 변수 교환

# 딕셔너리
# 딕셔너리화 : dict(zip(keys, values)) / {key: value for key, value in zip(keys, values)}
# 요소 삭제 : del dict[key] / pop(key) : 키 제거 후 값 반환 / popitem() : 마지막 요소 제거 후 (키, 값) 튜플 반환
# 안전한 접근 : dict.get(key, default) : 키가 없으면 default 반환 / dict.setdefault(key, default) : 키가 없으면 default로 설정 후 반환
# keys(), values(), items() : 각각 키, 값, (키, 값) 튜플 반환
# 딕셔너리 컴프리헨션 : {key: value for item
# ex. {x: x**2 for x in range(5)} # 0부터 4까지의 제곱을 값으로 하는 딕셔너리 생성
# 중첩이면 알아서 [n][m]


# [] : 빈리스트 / () : 빈튜플 / {} : 빈딕셔너리 / set() : 빈셋
# 두 set a, b : a | b : 합집합, a & b : 교집합, a - b : 차집합, a ^ b : 대칭차집합 ( 한쪽에만 있는거, a|b - a&b)
# 컴프리헨션시 {} 사용
# enumerate() : 리스트 요소와 인덱스 함께 반환
# zip() : 여러 리스트 요소를 튜플로 묶어서 반환
    # 길이가 다르면 짧은 쪽에 맞춤


# sort(x, key=함수) : 리스트 x를 함수의 반환값 기준으로 정렬
# lambda 간단한 익명 함수 : lambda 매개변수: 표현식

#진법 변환
# 2진수 : bin(x) / {x:b}, format(x, 'b') : b 진수로 변환
# 부동소수점 오차 : 알죠?
# Out:
# nohtyp

# %%
name = "Python"
print(f"{name:*^16}")
# Out:
# *****Python*****
